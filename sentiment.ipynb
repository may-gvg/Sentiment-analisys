# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 
import datetime as dt


# %matplotlib inline

# %%
import requests 
url = '########'

headers = {'accept': 'application/json', 'content-type': 'application/json'}
jsonobj = {'appId': ########, 'password': '#########'}
resp = requests.post(url=url, headers=headers, json=jsonobj)
data = resp.json()
token = data.get("access_token")

# %%
url3 = 'https://api.dev.timesheet.bcf-software.com/s2s/workdays/'


headers['Authorization'] = f"Bearer {token}"

resp = requests.get(url=url3, headers=headers)
data = resp.json()

# %%
df_com = pd.json_normalize(data)
df_com = df_com[['logDayFrom','user.firstName', 'user.lastName', 'comment']]

# %%
df3 =df_com[(df_com['logDayFrom'] >= '2020-11-01') & (df_com['logDayFrom'] < '2020-12-01')]

# %%
from textblob import TextBlob

for t in df3['comment']:
    testimonial = TextBlob(t)
    print(str(t) + " : " + str(testimonial.sentiment))
# Out:
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# worked on #51 Add possibility to edit calendar if user has rights and #82 Edit workday for other user : Sentiment(polarity=-0.125, subjectivity=0.375)
# Worked on #49 Optimization - get only necessary workdays in calendar, #89 Get only workdays from specific month and #85 Change names of reports for downloading : Sentiment(polarity=0.0, subjectivity=0.78125)
# Continue working on #89 Get only workdays from specific month and #85 Change names of reports for downloading : Sentiment(polarity=0.0, subjectivity=0.5625)
# Done #89 Get only workdays from specific month and #85 Change names of reports for downloading; Started working on #55 Bulk generate of project reports and #86 Select more than one project when user is generating project report : Sentiment(polarity=0.16666666666666666, subjectivity=0.5416666666666666)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# Ended working on #55 Bulk generate of project reports and #86 Select more than one project when user is generating project report : Sentiment(polarity=0.5, subjectivity=0.5)
# Working on #60 Fix rights related to tags : Sentiment(polarity=0.0, subjectivity=0.4)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# Unexpected sudden time off : Sentiment(polarity=0.05, subjectivity=0.75)
# Unexpected sudden time off : Sentiment(polarity=0.05, subjectivity=0.75)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# Discuss target architecture with Sławek, create an IoT "thing" for my device in AWS : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# Knowledge transfer & goodbye call : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# 720-10-mixpanel-user-events : Sentiment(polarity=0.0, subjectivity=0.0)
# 720-10-mixpanel-user-events
# 722-8-mixpanel-handover-events : Sentiment(polarity=0.0, subjectivity=0.0)
# 722-8-mixpanel-handover-events : Sentiment(polarity=0.0, subjectivity=0.0)
# 721-8-mixpanel-case-events : Sentiment(polarity=0.0, subjectivity=0.0)
# 721-8-mixpanel-case-events : Sentiment(polarity=0.0, subjectivity=0.0)
# 721-8-mixpanel-case-events : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# 723-6-mixpanel-cpd-events : Sentiment(polarity=0.0, subjectivity=0.0)
# 725-3-mixpanel-task-events
# 723-6-mixpanel-cpd-events : Sentiment(polarity=0.0, subjectivity=0.0)
# grooming
# meeting with Jean and Nicole to explain mixpanel
# 725-3-mixpanel-task-events : Sentiment(polarity=0.0, subjectivity=0.0)
# 732-1-too-many-users-created-in-mixpanel
# 731-2-mixpanel-investigate-cohort-to-do-alalysys-per-user
# done release build
# analysis of bugs happend on release build
# (1. packages conneted to attachments need to be downgrade, 2. typescript version needs to be downgrade, 3. needs to disable protractor tests to make proper buil for now) : Sentiment(polarity=0.0, subjectivity=0.1)
# downgrade packages connected to opening attachments
# downgrade typescript package to 2.6.2
# asked Dawid to disable protractor test to make proper release build : Sentiment(polarity=0.0, subjectivity=0.1)
# prepare testflight with dawid to test attachments on ios
# 724-6-cpd-open-attachments-on-ios : Sentiment(polarity=0.0, subjectivity=0.0)
# 724-6-cpd-open-attachments-on-ios : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# Feature - add menage tags : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# Project work in SCRUM : Sentiment(polarity=0.0, subjectivity=0.0)
# Project work in SCRUM : Sentiment(polarity=0.0, subjectivity=0.0)
# Project work in SCRUM : Sentiment(polarity=0.0, subjectivity=0.0)
# Project work in SCRUM : Sentiment(polarity=0.0, subjectivity=0.0)
# Project work in SCRUM : Sentiment(polarity=0.0, subjectivity=0.0)
# Project work in SCRUM : Sentiment(polarity=0.0, subjectivity=0.0)
# Project work in SCRUM : Sentiment(polarity=0.0, subjectivity=0.0)
# Project work in SCRUM : Sentiment(polarity=0.0, subjectivity=0.0)
# Project work in SCRUM : Sentiment(polarity=0.0, subjectivity=0.0)
# Project work in SCRUM : Sentiment(polarity=0.0, subjectivity=0.0)
# Project work in SCRUM : Sentiment(polarity=0.0, subjectivity=0.0)
# Project work in SCRUM : Sentiment(polarity=0.0, subjectivity=0.0)
# Project work in SCRUM : Sentiment(polarity=0.0, subjectivity=0.0)
# Project work in SCRUM : Sentiment(polarity=0.0, subjectivity=0.0)
# Project work in SCRUM : Sentiment(polarity=0.0, subjectivity=0.0)
# Project work in SCRUM : Sentiment(polarity=0.0, subjectivity=0.0)
# Project work in SCRUM : Sentiment(polarity=0.0, subjectivity=0.0)
# Project work in SCRUM : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# introducing the trainee to the project;
# https://gitlab.com/brightcodersfactory/internal-timesheet-project/timesheet-api/-/issues/50 : Sentiment(polarity=0.0, subjectivity=0.0)
# https://trello.com/c/1eC3RWpn/672-6-check-current-user-on-admin-panel-and-his-permission-if-he-is-admin : Sentiment(polarity=0.0, subjectivity=0.0)
# Add options for empty values in ECDIS 1 and ECDIS 2 : Sentiment(polarity=-0.1, subjectivity=0.5)
# 2.11.2020 - 4h
#
# testy: Arc4Health 2020-10-30 Software System Test Level for version 2.4.0 (#8FD51D87) : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# LB power consumption measurements
# Optimizing power consumption   : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# Sprint planning, backlog updates, update program statuses in a spreadsheet : Sentiment(polarity=0.0, subjectivity=0.0)
# ARAW's stage server deploy replacement : Sentiment(polarity=0.0, subjectivity=0.0)
# Preliminary clock frequency and temperature measurements, summarize work status and conclusions : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# - openfaas function building and deploying improvements
# - helm troubleshooting
# - monitoring improvements
# - campaigns supervision : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# - npm package build process implementation
# - production troubleshooting
# - implementing WAF with external provider : Sentiment(polarity=0.0, subjectivity=0.1)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# - api gateway troubleshooting
# - aws es backup process creation and implementation
# - various build processes optimizations
# - env specific services reachability implementation : Sentiment(polarity=0.0, subjectivity=0.3125)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# Feature - update manage tags and add tags in user settings : Sentiment(polarity=0.0, subjectivity=0.0)
# Praca z ogłaszeniami na pracuj pl;
# Umawianie ozmów kandydatom;
# Obserwacja nowych kandydatów z pracuj pl;
# Prowadzenie rozmowy rekrutacyjnej;
# Umawianie rozmowy technicznej;
# Wsparcie nowych pracowników; : Sentiment(polarity=0.0, subjectivity=0.0)
# Praca biurowa w PNT;
# Szukanie kandydatów na LinkedIn;
# Wybranie kandydatów z PracujPl;
# Umawianie i przeprowadzanie rozmów;
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# working with Sperry Site dev server on Ubuntu 20 : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# Continue https://gitlab.com/brightcodersfactory/internal-timesheet-project/timesheet-api/-/issues/50
# Consult the trainee  : Sentiment(polarity=0.0, subjectivity=0.0)
# https://trello.com/c/1eC3RWpn/672-6-check-current-user-on-admin-panel-and-his-permission-if-he-is-admin : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# implemented and tested reshaping the thermal frame and making an image out of it on 139 : Sentiment(polarity=0.0, subjectivity=0.0)
# preparation for and meeting with Marek regarding CAN protocol,
# few checks on RPIs  : Sentiment(polarity=-0.2, subjectivity=0.1)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# weekly, preparation for weekly, trying to get thermal frame through i2c, not detected, tried in next days (reporting here) consulted it with Andy on Wednesday : Sentiment(polarity=0.0, subjectivity=0.0)
# Urlop za 15.08 : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# Fixing prod : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# Implement new pages : Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# Implement new pages : Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# worked on #51 Add possibility to edit calendar if user has rights and #82 Edit workday for other user : Sentiment(polarity=-0.125, subjectivity=0.375)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# ARAW fixing Stage deployment : Sentiment(polarity=0.0, subjectivity=0.0)
# Help creating purchase order for BME sensor and connecting elements, see an issue with connecting BME and MLX to the same pins : Sentiment(polarity=0.0, subjectivity=0.125)
# Teasy: start reverse engineering .cfg options for the Gripper module : Sentiment(polarity=0.0, subjectivity=0.0)
# working on analysis of vendors results - new look at batch A as per request : Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# working on analysis of vendors' results - new look at Batch A as per request - mostly updating GT tables and scripts
# daily  : Sentiment(polarity=0.21212121212121213, subjectivity=0.3181818181818182)
# working on analysis of vendors' results - new look at Batch A as per request - GT tables
# daily : Sentiment(polarity=0.06818181818181818, subjectivity=0.22727272727272727)
# working on analysis of vendor results - new look at Batch A as per request - updated excel file results
# daily, meeting with one of the vendors : Sentiment(polarity=0.06818181818181818, subjectivity=0.22727272727272727)
# working on analysis of vendor results - new look at Batch A as per request - updated presentation final stage
# daily : Sentiment(polarity=0.04545454545454545, subjectivity=0.48484848484848486)
# one of the vendors APIs, docu etc. analysis : Sentiment(polarity=0.0, subjectivity=0.0)
# plan committed to github, docu reading, nlp readings, meeting with vendor, briefing : Sentiment(polarity=0.0, subjectivity=0.0)
# Changed default power off to three dots
# Started working on Pairing mode : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# Worked on #49 Optimization - get only necessary workdays in calendar, #89 Get only workdays from specific month and #85 Change names of reports for downloading : Sentiment(polarity=0.0, subjectivity=0.78125)
# Continue working on #89 Get only workdays from specific month and #85 Change names of reports for downloading : Sentiment(polarity=0.0, subjectivity=0.5625)
# Continue https://gitlab.com/brightcodersfactory/internal-timesheet-project/timesheet-api/-/issues/50
# Consult the trainee  : Sentiment(polarity=0.0, subjectivity=0.0)
# https://trello.com/c/1eC3RWpn/672-6-check-current-user-on-admin-panel-and-his-permission-if-he-is-admin : Sentiment(polarity=0.0, subjectivity=0.0)
# Refaktoryzacja scenariuszy testowych : Sentiment(polarity=0.0, subjectivity=0.0)
# Refaktoryzacja scenariuszy testowych : Sentiment(polarity=0.0, subjectivity=0.0)
# Upgrading ubuntu, migrate DB : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# Discuss target architecture with Sławek, create an IoT "thing" for my device in AWS : Sentiment(polarity=0.0, subjectivity=0.0)
# Teasy: reverse engineer .cfg options for the Gripper module : Sentiment(polarity=0.0, subjectivity=0.0)
# Szkolenie Clean Code : Sentiment(polarity=0.3666666666666667, subjectivity=0.7000000000000001)
# ARAW Prod API replacement : Sentiment(polarity=0.0, subjectivity=0.0)
# Reworking button handling in Controller : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# Setup Sperry Site on 172.16.1.98  : Sentiment(polarity=0.0, subjectivity=0.0)
# Szukanie kandydatów na LinkedIn;
# Wybranie kandydatów z PracujPl;
# Umawianie i przeprowadzanie rozmów;
# Multisport; : Sentiment(polarity=0.0, subjectivity=0.0)
# Szukanie kandydatów na LinkedIn;
# Wybranie kandydatów z PracujPl;
# Umawianie rozmów;
# Multisport; : Sentiment(polarity=0.0, subjectivity=0.0)
# Standard server maintenance; Tested initial Traefik configuration; Prepared files for switching from Nginx to Traefik; Research towards automatic certificate renew in Traefik; : Sentiment(polarity=0.0, subjectivity=0.0)
# Szkolenie Clean Code : Sentiment(polarity=0.3666666666666667, subjectivity=0.7000000000000001)
# Verify connection between my Pi board and the AWS "thing" : Sentiment(polarity=0.0, subjectivity=0.0)
# Teasy: make Gripper tabs display button labels and other texts based on configuration : Sentiment(polarity=-0.125, subjectivity=0.375)
# Done #89 Get only workdays from specific month and #85 Change names of reports for downloading; Started working on #55 Bulk generate of project reports and #86 Select more than one project when user is generating project report : Sentiment(polarity=0.16666666666666666, subjectivity=0.5416666666666666)
# Implementing pairing mode : Sentiment(polarity=0.0, subjectivity=0.0)
# Implement SearchPage : Sentiment(polarity=0.0, subjectivity=0.0)
# Implement SearchPage : Sentiment(polarity=0.0, subjectivity=0.0)
# Feature/Tags - last details,
# Feature/Report Productivity -  fixes and update,
# Meeting with Finalsite : Sentiment(polarity=0.0, subjectivity=0.06666666666666667)
# finish upgrading sperry site dev server : Sentiment(polarity=0.0, subjectivity=0.0)
# Continue https://gitlab.com/brightcodersfactory/internal-timesheet-project/timesheet-api/-/issues/50
# Created new association table, added saving data on BE and FE
# Consult the trainee  : Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# https://trello.com/c/1eC3RWpn/672-6-check-current-user-on-admin-panel-and-his-permission-if-he-is-admin : Sentiment(polarity=0.0, subjectivity=0.0)
# More research towards automatic certificate renewal with Traefik : Sentiment(polarity=0.5, subjectivity=0.5)
# Teasy (apply review comments), p0901 (fix nullptr crash on REST server error) : Sentiment(polarity=0.0, subjectivity=0.0)
# Comparative clock frequency and temperature measurements on 2 branches and 2 devices : Sentiment(polarity=0.0, subjectivity=0.0)
# Timesheet - optimized build process for mailer, simplified mailer execution, removed Ophelia cron task sheduler; ARAW - fixes to production API connection with archive domain : Sentiment(polarity=0.0, subjectivity=0.0)
# Szkolenie Cfam, refaktoryzacja scenariuszy testowych : Sentiment(polarity=0.0, subjectivity=0.0)
# ARAW - additional fixes to base API docker image, recreated from Fream sources : Sentiment(polarity=-0.8, subjectivity=1.0)
# Unexpected sudden time off : Sentiment(polarity=0.05, subjectivity=0.75)
# Unexpected sudden time off : Sentiment(polarity=0.05, subjectivity=0.75)
# Investigate translations; Call with REST team : Sentiment(polarity=0.0, subjectivity=0.0)
# Investigate translations; Call with Roche : Sentiment(polarity=0.0, subjectivity=0.0)
# Investigate translations; Call with Roche; Teasy : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# - zmiany w hot migracji. wymuszenie 2-etapowego logowania (dodanie kroku z OTP) w przypadku gdy migrowany uzytkownik nie zweryfikowal tokena
# - mechanizm asynchronicznych, uniwersalnych webhookow w network users celem karmienia zewnetrznych narzedzi.
# - integracja webhookow z user consents : Sentiment(polarity=0.25, subjectivity=0.8500000000000001)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# presentation for CTO, daily, meeting with CTO : Sentiment(polarity=0.0, subjectivity=0.0)
# presentation for CTO, updated CE results : Sentiment(polarity=0.0, subjectivity=0.0)
# Presentation for CTO : Sentiment(polarity=0.0, subjectivity=0.0)
# Presentation for CTO, daily, meeting with CTO : Sentiment(polarity=0.0, subjectivity=0.0)
# working on HS results : Sentiment(polarity=0.0, subjectivity=0.0)
# working on HS results
# daily : Sentiment(polarity=0.0, subjectivity=0.0)
# metrics GT matrix update (strong, good) and HS rerun for them, daily : Sentiment(polarity=0.37777777777777777, subjectivity=0.4444444444444445)
# metrics GT matrix update (strong, good) and HS rerun for them,
# daily : Sentiment(polarity=0.37777777777777777, subjectivity=0.4444444444444445)
# Create validation function : Sentiment(polarity=0.0, subjectivity=0.0)
# Create sample validation for apiStatus and idMappingTool
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# working on analysis of vendors results : Sentiment(polarity=0.0, subjectivity=0.0)
# working on analysis of vendors results : Sentiment(polarity=0.0, subjectivity=0.0)
# working on analysis of vendor results - new look at Batch A as per request
# daily  : Sentiment(polarity=0.06818181818181818, subjectivity=0.22727272727272727)
# tasks estimation, meeting with Marek, sharepoint space  : Sentiment(polarity=0.0, subjectivity=0.0)
# tasks estimation, meeting with Marek, sharepoint space  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# testing on the rpis over vpn,  preparation for weekly, weekly : Sentiment(polarity=0.0, subjectivity=0.0)
# testing on the rpis over vpn,  preparation for weekly, weekly : Sentiment(polarity=0.0, subjectivity=0.0)
# Create validation error component : Sentiment(polarity=0.0, subjectivity=0.0)
# Further work on style guide : Sentiment(polarity=0.0, subjectivity=0.5)
# Further work on style guide : Sentiment(polarity=0.0, subjectivity=0.5)
# Project Theme Plus - initial settings and edit homepage : Sentiment(polarity=0.0, subjectivity=0.0)
# ARAW - analyzing and fixing of production critical error from saturday; updated Dockerfiles based on documentation update : Sentiment(polarity=0.0, subjectivity=0.8)
# Timesheet - testing and implementation of distroless Docker images to improve security : Sentiment(polarity=0.0, subjectivity=0.0)
# Summarize temperature data, attempt to increase camera baudrate : Sentiment(polarity=0.0, subjectivity=0.0)
# Sprint planning, Teasy (learn how the legacy code uses configuration options for the BARCODE module) : Sentiment(polarity=0.0, subjectivity=0.0)
# Refaktoryzacja scenariuszy testowych : Sentiment(polarity=0.0, subjectivity=0.0)
# Fixing some troubles with pairing mode : Sentiment(polarity=0.0, subjectivity=0.0)
# Refactoring buttons handling and implementing pairing mode : Sentiment(polarity=0.0, subjectivity=0.0)
# final corrections : Sentiment(polarity=0.0, subjectivity=1.0)
# Check relation in PS DB. Fix problem with VM : Sentiment(polarity=0.0, subjectivity=0.0)
# Refaktoryzacja kodu SCT, wdrozenie : Sentiment(polarity=0.0, subjectivity=0.0)
# Refaktoryzacja kodu SCT, wdrozenie : Sentiment(polarity=0.0, subjectivity=0.0)
# Refaktoryzacja kodu SCT, wdrozenie : Sentiment(polarity=0.0, subjectivity=0.0)
# Refaktoryzacja kodu SCT, wdrozenie : Sentiment(polarity=0.0, subjectivity=0.0)
# Refaktoryzacja kodu SCT, wdrozenie : Sentiment(polarity=0.0, subjectivity=0.0)
# Refaktoryzacja kodu SCT, wdrozenie : Sentiment(polarity=0.0, subjectivity=0.0)
# Refaktoryzacja kodu SCT, wdrozenie : Sentiment(polarity=0.0, subjectivity=0.0)
# Refaktoryzacja kodu SCT, wdrozenie : Sentiment(polarity=0.0, subjectivity=0.0)
# Refaktoryzacja kodu SCT, wdrozenie : Sentiment(polarity=0.0, subjectivity=0.0)
# Refaktoryzacja kodu SCT, wdrozenie : Sentiment(polarity=0.0, subjectivity=0.0)
# Refaktoryzacja kodu SCT, wdrozenie : Sentiment(polarity=0.0, subjectivity=0.0)
# Refaktoryzacja kodu SCT, wdrozenie : Sentiment(polarity=0.0, subjectivity=0.0)
# Refaktoryzacja kodu SCT, wdrozenie : Sentiment(polarity=0.0, subjectivity=0.0)
# Refaktoryzacja kodu SCT, wdrozenie : Sentiment(polarity=0.0, subjectivity=0.0)
# Refaktoryzacja kodu SCT, wdrozenie : Sentiment(polarity=0.0, subjectivity=0.0)
# Refaktoryzacja kodu SCT, wdrozenie : Sentiment(polarity=0.0, subjectivity=0.0)
# Refaktoryzacja kodu SCT, wdrozenie : Sentiment(polarity=0.0, subjectivity=0.0)
# Refaktoryzacja kodu SCT, wdrozenie : Sentiment(polarity=0.0, subjectivity=0.0)
# Refaktoryzacja kodu SCT, wdrozenie : Sentiment(polarity=0.0, subjectivity=0.0)
# Refaktoryzacja kodu SCT, wdrozenie : Sentiment(polarity=0.0, subjectivity=0.0)
# Refaktoryzacja kodu SCT, wdrozenie : Sentiment(polarity=0.0, subjectivity=0.0)
# Refaktoryzacja kodu SCT, wdrozenie : Sentiment(polarity=0.0, subjectivity=0.0)
# Refaktoryzacja kodu SCT, wdrozenie : Sentiment(polarity=0.0, subjectivity=0.0)
# Refaktoryzacja kodu SCT, wdrozenie : Sentiment(polarity=0.0, subjectivity=0.0)
# Refaktoryzacja kodu SCT, wdrozenie : Sentiment(polarity=0.0, subjectivity=0.0)
# Refaktoryzacja kodu SCT, wdrozenie : Sentiment(polarity=0.0, subjectivity=0.0)
# Refaktoryzacja kodu SCT, wdrozenie : Sentiment(polarity=0.0, subjectivity=0.0)
# Server maintenance; Database backup; Caches cleanup; Services healthcheck : Sentiment(polarity=0.0, subjectivity=0.0)
# Adjust app to portrait orientation : Sentiment(polarity=0.0, subjectivity=0.0)
# Adjust app to portrait orientation : Sentiment(polarity=0.0, subjectivity=0.0)
# Teasy (Print barcode): display UI texts based on configuration : Sentiment(polarity=0.0, subjectivity=0.0)
# Start looking at deltathermal-webapp code, attempt to resolve dependencies to run locally : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# Fixed national characters in End User Site JSONs.
# Added new fields related to company to Market Data and ensured that they will not be overwritten during import of data.
# Added new fields related to License to the Excel sheet generated on the License Server.
# Updated Market Data database with new data that Jens sent.
# Fixed a bug on the License Server that caused Excel sheet to be generated incorrectly when Expire Status was the last line in the Note field and it was empty. : Sentiment(polarity=0.05656565656565656, subjectivity=0.34781144781144785)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# Fixed an issue that sometimes caused script to generate End User Site JSONs to stutter in the middle, thus not generating them.
# End User Site refactoring - cleaned existing code, rewrited methods, removed unnecessary stuff, improved code readability and reduced its complexity (also apply to Market Data API). : Sentiment(polarity=-0.10000000000000002, subjectivity=0.3666666666666667)
# ARAW - prod and stage database backup -> loaded prod data to stage and modified sensitive data (caught version mismatch error in tools we typically use, had to do it the other way around); started admin-panel on stage from customized docker image : Sentiment(polarity=-0.06388888888888888, subjectivity=0.5916666666666667)
# Research options for unlocking the door : Sentiment(polarity=0.0, subjectivity=0.0)
# Research options for unlocking the door : Sentiment(polarity=0.0, subjectivity=0.0)
# Refaktoryzacja kodu SCT, wdrozenie : Sentiment(polarity=0.0, subjectivity=0.0)
# Finalizing project : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# Enable SOS signal from standby mode : Sentiment(polarity=0.0, subjectivity=0.0)
# Enable SOS signal from standby mode : Sentiment(polarity=0.0, subjectivity=0.0)
# Enable SOS signal from standby mode : Sentiment(polarity=0.0, subjectivity=0.0)
# Verify the possibility of adjusting sound volume for wav files : Sentiment(polarity=0.4, subjectivity=0.4)
# Verify the possibility of adjusting sound volume for wav files : Sentiment(polarity=0.4, subjectivity=0.4)
# Handle LifeBand lost scenario logic with different water temperature and boat speeds.
# ...
# 9.00-9.30 - Daily Tag Meeting
# 9.30-10.00 Sprawdzanie i odpisywanie na wiadomości kandytatów na LinkedIn : Sentiment(polarity=0.0, subjectivity=0.0)
# Daily Tag Meeting
# Sprawdzanie i odpisywanie na wiadomości kandytatów na LinkedIn
# Rekrutacja/wyszukiwanie kandydatów C++ LinkedIn
# Rekrutacja/wyszukiwanie kandydatów Angular LinkedIn : Sentiment(polarity=0.0, subjectivity=0.0)
# Daily Tag Meeting
# Sprawdzanie i odpisywanie na wiadomości kandytatów na LinkedIn
# Rekrutacja/wyszukiwanie kandydatów C++ LinkedIn
# Rekrutacja/wyszukiwanie kandydatów Angular LinkedIn : Sentiment(polarity=0.0, subjectivity=0.0)
# 9.00-9.20 - Daily Tag Meeting
# 9.20 - 10.00 - Sprawdzanie i odpisywanie na wiadomości kandytatów na LinkedIn : Sentiment(polarity=0.0, subjectivity=0.0)
# 9.00 - 9.20 - Daily Tag Meeting
# 9.20 - 10.00 - Sprawdzanie i odpisywanie na wiadomości kandytatów na LinkedIn / Screening kandytada / planowanie rozmowy technicznej
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# Daily Tag Meeting
# Sprawdzanie i odpisywanie na wiadomości kandytatów na LinkedIn
# Rekrutacja/wyszukiwanie kandydatów C++ LinkedIn
# Rekrutacja/wyszukiwanie kandydatów Angular LinkedIn : Sentiment(polarity=0.0, subjectivity=0.0)
# Daily Tag Meeting
# Sprawdzanie i odpisywanie na wiadomości kandytatów na LinkedIn
# Rekrutacja/wyszukiwanie kandydatów C++ LinkedIn
# Rekrutacja/wyszukiwanie kandydatów Angular LinkedIn : Sentiment(polarity=0.0, subjectivity=0.0)
# 9.00-9.20 - Daily Tag Meeting
# 9.20 - 10.00 - Sprawdzanie i odpisywanie na wiadomości kandytatów na LinkedIn : Sentiment(polarity=0.0, subjectivity=0.0)
# 9.00-9.20 - Daily Tag Meeting
# 9.20 - 10.00 - Sprawdzanie i odpisywanie na wiadomości kandytatów na LinkedIn : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# Project work in SCRUM : Sentiment(polarity=0.0, subjectivity=0.0)
# Project work in SCRUM : Sentiment(polarity=0.0, subjectivity=0.0)
# Project work in SCRUM : Sentiment(polarity=0.0, subjectivity=0.0)
# Project work in SCRUM : Sentiment(polarity=0.0, subjectivity=0.0)
# Project work in SCRUM : Sentiment(polarity=0.0, subjectivity=0.0)
# Project work in SCRUM : Sentiment(polarity=0.0, subjectivity=0.0)
# Project work in SCRUM : Sentiment(polarity=0.0, subjectivity=0.0)
# Project work in SCRUM : Sentiment(polarity=0.0, subjectivity=0.0)
# Project work in SCRUM : Sentiment(polarity=0.0, subjectivity=0.0)
# Project work in SCRUM : Sentiment(polarity=0.0, subjectivity=0.0)
# Project work in SCRUM : Sentiment(polarity=0.0, subjectivity=0.0)
# Project work in SCRUM : Sentiment(polarity=0.0, subjectivity=0.0)
# Project work in SCRUM : Sentiment(polarity=0.0, subjectivity=0.0)
# Project work in SCRUM : Sentiment(polarity=0.0, subjectivity=0.0)
# Project work in SCRUM : Sentiment(polarity=0.0, subjectivity=0.0)
# Project work in SCRUM : Sentiment(polarity=0.0, subjectivity=0.0)
# Project work in SCRUM : Sentiment(polarity=0.0, subjectivity=0.0)
# Project work in SCRUM : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# Project delivery : Sentiment(polarity=0.0, subjectivity=0.0)
# SCRUM work : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# Further deployment of applications on new SoYouStart server.
# Deployed Gogs, Drone, fixed database instances : Sentiment(polarity=0.07878787878787878, subjectivity=0.38484848484848483)
# Resolving issues with DOSA builds. Restoring old workspace : Sentiment(polarity=0.1, subjectivity=0.2)
# Moved ARAW dev and production deployment to SoYouStart server. : Sentiment(polarity=0.0, subjectivity=0.0)
# Naprawa błędów związanych z wysyłaniem pliku upo.xml : Sentiment(polarity=0.0, subjectivity=0.0)
# Mute override, Translations, version bug fixing : Sentiment(polarity=0.0, subjectivity=0.0)
# Mute override, Translations, version bug fixing : Sentiment(polarity=0.0, subjectivity=0.0)
# Mute override, Translations, version bug fixing : Sentiment(polarity=0.0, subjectivity=0.0)
# 0,5hr DM team meeting; 1hr SF mapping, 4,5 hrs of mapping template preparation for S4/Hana : Sentiment(polarity=0.0, subjectivity=0.0)
# 0,5hr DM team meeting; 1hr SF mapping, 4,5 hrs of mapping template preparation for S4/Hana : Sentiment(polarity=0.0, subjectivity=0.0)
# Spotkania z partnerami, praca nad funkcjonalnością i strukturą projektu związaną z API i frontend : Sentiment(polarity=0.0, subjectivity=0.0)
# Spotkania z partnerami, praca nad funkcjonalnością i strukturą projektu związaną z API i frontend : Sentiment(polarity=0.0, subjectivity=0.0)
# Spotkania z partnerami, praca nad funkcjonalnością i strukturą projektu związaną z API i frontend : Sentiment(polarity=0.0, subjectivity=0.0)
# Naprawa błędu z wyświetlaniem projektów bez aktualnego FTE, wystawienie MR. : Sentiment(polarity=0.0, subjectivity=0.0)
# Naprawa błędu z wyświetlaniem projektów bez aktualnego FTE, wystawienie MR. : Sentiment(polarity=0.0, subjectivity=0.0)
# Próba pobierania danych ze streamu i wyświetlanie w panelu. : Sentiment(polarity=0.0, subjectivity=0.0)
# Próba pobierania danych ze streamu i wyświetlanie w panelu. : Sentiment(polarity=0.0, subjectivity=0.0)
# Naprawa błędów w aplikacji Nasz Wrocław, testowanie, wygenerowanie nowego apk : Sentiment(polarity=0.0, subjectivity=0.0)
# Naprawa błędów w aplikacji Nasz Wrocław, testowanie, wygenerowanie nowego apk : Sentiment(polarity=0.0, subjectivity=0.0)
# Spring Cloud Config Service - Data Flow implementacja lokalna : Sentiment(polarity=0.0, subjectivity=0.0)
# Spring Cloud Config Service - Data Flow implementacja lokalna. Utworzenie struktury katalogów w repo Cloud Config Server. : Sentiment(polarity=0.0, subjectivity=0.0)
# Widget update, updating Twilio version : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# 2020.11.02 - 2020.11.06
# - Projects: Timesheet, Management, ZeaEye, Medixus, WelcomeBob, MBO Partners (Integrations, Data Migration), Danelec, BlockV koordynacja.
# - Support: Delta Thermal
# - 1to1:  Mateusz Grzegorzek, Arleta Witke, Wiktoria Stefaniak,
# - Interview:
# - Customer: Digital Canvas, Euvic Austria, Euvic Polska,  Automatek,  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# 2020.11.09 - 2020.11.12
# - Projects: Timesheet, Management, ZeaEye, Medixus, WelcomeBob, MBO Partners (Integrations, Data Migration), Danelec, BlockV koordynacja.
# - Support: Delta Thermal, Nokia IoT,
# - 1to1: Piotr Solarz-Wnek, Alicja Portas
# - Interview:  Benoit Viganotti
# - Customer: Digital Canvas, Euvic Austria, Euvic Polska,  Automatek, Korea Follow-up. : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# 2020.11.16 - 2020.11.20
# - Projects: Timesheet, Management,  Medixus, WelcomeBob, MBO Partners (Integrations, Data Migration), Danelec, BlockV koordynacja.
# - Support: Delta Thermal, Nokia IoT,
# - 1to1: Dariusz Wysocki, Łukasz Szklarski, Alicja Portas,
# - Interview: Tomasz Tokarski,   Paweł Bober, Piotr Perek,
# - Slack configuration / Wiktoria Stefaniak.
# - Customer: Digital Canvas, Euvic Austria, Euvic Polska,  Automatek, Korea Follow-up, PwC Czech,  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# 2020.11.23 - 2020.11.27
# - Projects: Timesheet, Management, Medixus, WelcomeBob, MBO Partners (Integrations, Data Migration), Danelec, BlockV koordynacja.
# - Support: Delta Thermal, Nokia IoT, Demo Open Vino.
# - 1to1: Dorota Badura, Ida Czyrek, Przemyslaw Bobnis
# - Interview: Michał Kopeć,  Tomasz Kowalczyk (Praktyki), Mateusz Zatorski, TAG Interviews, PwC (Piotr Solarz Wnek), (PwC) Przemyslaw Wlodarczyk
# - Antenas System ops preparation.
# - Customer: Digital Canvas, Euvic Austria, Euvic Polska,  Automatek, Korea , PwC Czech,  : Sentiment(polarity=0.0, subjectivity=0.25)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# - openfaas function building and deploying improvements
# - helm troubleshooting
# - monitoring improvements
# - campaigns supervision : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# - npm package build process implementation
# - production troubleshooting
# - implementing WAF with external provider : Sentiment(polarity=0.0, subjectivity=0.1)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# - api gateway troubleshooting
# - aws es backup process creation and implementation
# - various build processes optimizations
# - env specific services reachability implementation : Sentiment(polarity=0.0, subjectivity=0.3125)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# - dev env code optimizations
# - aws es backup deployment  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# Consult trainee, Continue https://gitlab.com/brightcodersfactory/internal-timesheet-project/timesheet-api/-/issues/50 Change the logig for the works loading on PKUP, add the modal with the list of works to be accepted and the funtionality ty accept it.  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# Change merge requests on FE and BE due to the comments.
#  https://gitlab.com/brightcodersfactory/internal-timesheet-project/timesheet-api/-/issues/50  : Sentiment(polarity=-0.125, subjectivity=0.375)
# vendor integration - documentation / env installation / choosing data : Sentiment(polarity=0.0, subjectivity=0.0)
# Moved the logic to load works for pkup and the works for user where he is co-author to BE from FE. Added new endpoints.  https://gitlab.com/brightcodersfactory/internal-timesheet-project/timesheet-api/-/issues/50  : Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# Create new tab on menu FE : Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# 1. https://trello.com/c/aRgo9Ebd/707-9-investigate-tools-drone-configuration-and-update-to-visualize-results-objective-to-monitor-pass-fail-ratio-of-all-automated-te : Sentiment(polarity=0.0, subjectivity=0.0)
# vendor itegration - trying to connect to sandbox and resolving modules issues : Sentiment(polarity=0.0, subjectivity=0.0)
# vendor results interpretation, integration project, presentation modification : Sentiment(polarity=0.0, subjectivity=0.0)
# vendor integration - documentation / env installation / choosing data : Sentiment(polarity=0.0, subjectivity=0.0)
# vendor itegration - trying to connect to sandbox and resolving modules issues : Sentiment(polarity=0.0, subjectivity=0.0)
# vendor results interpretation, integration project, presentation modification : Sentiment(polarity=0.0, subjectivity=0.0)
# Tried to detect and shoot images on 139, dependencies installation (it's totally undocumented, only some readme.md, doing it blindly from some descriptions from internet). (this is logged for both 16th and 17th) : Sentiment(polarity=-0.16666666666666666, subjectivity=0.8055555555555555)
# Tried to detect and shoot images on 139, dependencies installation (it's totally undocumented, only some readme.md, doing it blindly from some descriptions from internet). (this is logged for both 16th and 17th) : Sentiment(polarity=-0.16666666666666666, subjectivity=0.8055555555555555)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# SQS encryption / Plaftorm AMI onboading / Dev support : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# Plaftorm AMI onboading / Dev support : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# SQS encryption / Dev support / Meddream task : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# SQS encryption : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
# SSIS ETL preparation (DB2 to SQLServer, local mapping)
# DM Meetings : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)
#  : Sentiment(polarity=0.0, subjectivity=0.0)

# %%
df3["subjectivity"] = df3.apply(lambda x: TextBlob(x['comment']).sentiment.subjectivity, axis = 1)

# %%
df_com = df_com[df_com.comment != '']

# %%
df_com.sort_values(by='userId',ascending=True)
# Out:
#       userId           logDayFrom             logDayTo  \
# 2116      10  2022-05-12 07:00:00  2022-05-12 15:00:00
# 241       10  2020-10-14 08:00:00  2020-10-14 16:00:00
# 1222      10  2020-11-05 08:00:00  2020-11-05 16:00:00
# 1234      10  2020-11-06 08:00:00  2020-11-06 16:00:00
# 1278      10  2020-11-10 08:00:00  2020-11-10 16:00:00
# ...      ...                  ...                  ...
# 2003      69  2020-11-30 12:00:00  2020-11-30 18:00:00
# 1792      69  2020-11-24 13:00:00  2020-11-24 17:30:00
# 1488      69  2020-11-03 14:00:00  2020-11-03 17:00:00
# 2064      69  2020-12-30 12:00:00  2020-12-30 18:00:00
# 2056      69  2020-12-16 12:00:00  2020-12-16 18:00:00
#
#                                                 comment
# 2116                                               test
# 241   Reviewing code of Sperry Site. Trying to resol...
# 1222                  Setup Sperry Site on 172.16.1.98
# 1234            finish upgrading sperry site dev server
# 1278       Check relation in PS DB. Fix problem with VM
# ...                                                 ...
# 2003  0,5hr DM team meeting; 1hr SF mapping, 4,5 hrs...
# 1792  0,5hr DM team meeting; 1hr SF mapping, 3 hrs o...
# 1488         Wrap up calls, data mapping sessions, etc.
# 2064  S4 Mapping preparation incl. Templates, S4 des...
# 2056  S4 Mapping preparation incl. Templates, S4 des...
#
# [2117 rows x 4 columns]

# %% [markdown]
# quering user id

# %%
df_com.query('userId == 20', inplace = True)

# %%
df_com
# Out:
#       userId           logDayFrom             logDayTo  \
# 16        20  2020-08-18 08:30:00  2020-08-18 09:30:00
# 184       20  2020-09-01 16:15:00  2020-09-01 18:45:00
# 210       20  2020-10-08 13:00:00  2020-10-08 23:00:00
# 211       20  2020-10-05 20:00:00  2020-10-05 23:30:00
# 212       20  2020-10-14 20:00:00  2020-10-14 23:00:00
# ...      ...                  ...                  ...
# 2037      20  2020-11-26 10:00:00  2020-11-26 18:00:00
# 2038      20  2020-11-27 10:00:00  2020-11-27 18:00:00
# 2039      20  2020-11-30 10:30:00  2020-11-30 18:30:00
# 2040      20  2020-11-16 20:00:00  2020-11-16 21:00:00
# 2041      20  2020-11-16 20:00:00  2020-11-16 21:00:00
#
#                                                 comment
# 16                                 B+R doc. preparation
# 184   EdgeIQ deltathermal preparation and meeting (w...
# 210   preparing training set for vendors (dividing c...
# 211   meeting, continuing with the can, checking AWS...
# 212   sent 2kB for the first time with new hardware ...
# ...                                                 ...
# 2037  vendor integration - documentation / env insta...
# 2038  vendor itegration - trying to connect to sandb...
# 2039  vendor results interpretation, integration pro...
# 2040  Tried to detect and shoot images on 139, depen...
# 2041  Tried to detect and shoot images on 139, depen...
#
# [114 rows x 4 columns]

# %%
df_com.describe()
# Out:
#        userId
# count   114.0
# mean     20.0
# std       0.0
# min      20.0
# 25%      20.0
# 50%      20.0
# 75%      20.0
# max      20.0

# %% [markdown]
# date

# %%
df3 =df_com[(df_com['logDayFrom'] >= '2020-11-01') & (df_com['logDayFrom'] < '2020-12-01')]
df3
# Out:
#       userId           logDayFrom             logDayTo  \
# 1190      20  2020-11-24 20:00:00  2020-11-24 22:00:00
# 1191      20  2020-11-25 20:00:00  2020-11-25 22:00:00
# 1192      20  2020-11-09 18:00:00  2020-11-09 23:00:00
# 1202      20  2020-11-10 12:00:00  2020-11-10 20:00:00
# 1203      20  2020-11-12 12:00:00  2020-11-12 20:00:00
# ...      ...                  ...                  ...
# 2037      20  2020-11-26 10:00:00  2020-11-26 18:00:00
# 2038      20  2020-11-27 10:00:00  2020-11-27 18:00:00
# 2039      20  2020-11-30 10:30:00  2020-11-30 18:30:00
# 2040      20  2020-11-16 20:00:00  2020-11-16 21:00:00
# 2041      20  2020-11-16 20:00:00  2020-11-16 21:00:00
#
#                                                 comment
# 1190  implemented and tested reshaping the thermal f...
# 1191  preparation for and meeting with Marek regardi...
# 1192  weekly, preparation for weekly, trying to get ...
# 1202  working on analysis of vendors results - new l...
# 1203  working on analysis of vendors' results - new ...
# ...                                                 ...
# 2037  vendor integration - documentation / env insta...
# 2038  vendor itegration - trying to connect to sandb...
# 2039  vendor results interpretation, integration pro...
# 2040  Tried to detect and shoot images on 139, depen...
# 2041  Tried to detect and shoot images on 139, depen...
#
# [66 rows x 4 columns]

# %% [markdown]
# df_com['logDayFrom'] = pd.to_datetime(df_com['logDayFrom'], errors='coerce')
# df_com['logDayFrom'] = pd.to_datetime(df_com["logDayFrom"].dt.strftime('%Y-%m'))
# df_data20 = df_com[(df_com['logDayFrom'] >= '2020-11-01') & (df_com['logDayFrom'] < '2020-12-01')]

# %%
pip install TextBlob
# Out:
# Requirement already satisfied: TextBlob in c:\projekty\pythonproject4\venv\lib\site-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in c:\projekty\pythonproject4\venv\lib\site-packages (from TextBlob) (3.6.7)
# Requirement already satisfied: tqdm in c:\projekty\pythonproject4\venv\lib\site-packages (from nltk>=3.1->TextBlob) (4.62.3)
# Requirement already satisfied: click in c:\projekty\pythonproject4\venv\lib\site-packages (from nltk>=3.1->TextBlob) (8.0.3)
# Requirement already satisfied: joblib in c:\projekty\pythonproject4\venv\lib\site-packages (from nltk>=3.1->TextBlob) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\projekty\pythonproject4\venv\lib\site-packages (from nltk>=3.1->TextBlob) (2022.1.18)
# Requirement already satisfied: colorama in c:\projekty\pythonproject4\venv\lib\site-packages (from click->nltk>=3.1->TextBlob) (0.4.4)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.3.1; however, version 22.2.2 is available.
# You should consider upgrading via the 'c:\projekty\pythonproject4\venv\scripts\python.exe -m pip install --upgrade pip' command.

# %%
df_com = df3

# %%
from textblob import TextBlob

for t in df_com['comment']:
    testimonial = TextBlob(t)
    print(str(t) + " : " + str(testimonial.sentiment))
# Out:
# implemented and tested reshaping the thermal frame and making an image out of it on 139 : Sentiment(polarity=0.0, subjectivity=0.0)
# preparation for and meeting with Marek regarding CAN protocol,
# few checks on RPIs  : Sentiment(polarity=-0.2, subjectivity=0.1)
# weekly, preparation for weekly, trying to get thermal frame through i2c, not detected, tried in next days (reporting here) consulted it with Andy on Wednesday : Sentiment(polarity=0.0, subjectivity=0.0)
# working on analysis of vendors results - new look at batch A as per request : Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# working on analysis of vendors' results - new look at Batch A as per request - mostly updating GT tables and scripts
# daily  : Sentiment(polarity=0.21212121212121213, subjectivity=0.3181818181818182)
# working on analysis of vendors' results - new look at Batch A as per request - GT tables
# daily : Sentiment(polarity=0.06818181818181818, subjectivity=0.22727272727272727)
# working on analysis of vendor results - new look at Batch A as per request - updated excel file results
# daily, meeting with one of the vendors : Sentiment(polarity=0.06818181818181818, subjectivity=0.22727272727272727)
# working on analysis of vendor results - new look at Batch A as per request - updated presentation final stage
# daily : Sentiment(polarity=0.04545454545454545, subjectivity=0.48484848484848486)
# one of the vendors APIs, docu etc. analysis : Sentiment(polarity=0.0, subjectivity=0.0)
# plan committed to github, docu reading, nlp readings, meeting with vendor, briefing : Sentiment(polarity=0.0, subjectivity=0.0)
# presentation for CTO, daily, meeting with CTO : Sentiment(polarity=0.0, subjectivity=0.0)
# presentation for CTO, updated CE results : Sentiment(polarity=0.0, subjectivity=0.0)
# Presentation for CTO : Sentiment(polarity=0.0, subjectivity=0.0)
# Presentation for CTO, daily, meeting with CTO : Sentiment(polarity=0.0, subjectivity=0.0)
# working on HS results : Sentiment(polarity=0.0, subjectivity=0.0)
# working on HS results
# daily : Sentiment(polarity=0.0, subjectivity=0.0)
# metrics GT matrix update (strong, good) and HS rerun for them, daily : Sentiment(polarity=0.37777777777777777, subjectivity=0.4444444444444445)
# metrics GT matrix update (strong, good) and HS rerun for them,
# daily : Sentiment(polarity=0.37777777777777777, subjectivity=0.4444444444444445)
# working on analysis of vendors results : Sentiment(polarity=0.0, subjectivity=0.0)
# working on analysis of vendors results : Sentiment(polarity=0.0, subjectivity=0.0)
# working on analysis of vendor results - new look at Batch A as per request
# daily  : Sentiment(polarity=0.06818181818181818, subjectivity=0.22727272727272727)
# tasks estimation, meeting with Marek, sharepoint space  : Sentiment(polarity=0.0, subjectivity=0.0)
# tasks estimation, meeting with Marek, sharepoint space  : Sentiment(polarity=0.0, subjectivity=0.0)
# testing on the rpis over vpn,  preparation for weekly, weekly : Sentiment(polarity=0.0, subjectivity=0.0)
# testing on the rpis over vpn,  preparation for weekly, weekly : Sentiment(polarity=0.0, subjectivity=0.0)
# weekly, preparation for weekly, trying to get thermal frame through i2c, not detected, tried in next days (reporting here) consulted it with Andy on Wednesday : Sentiment(polarity=0.0, subjectivity=0.0)
# installing dependencies on .139 (possible ABI issues)
# meeting with Marek
# weekly : Sentiment(polarity=0.0, subjectivity=1.0)
# installing dependencies on .139 (possible ABI issues)
# meeting with Marek
# weekly : Sentiment(polarity=0.0, subjectivity=1.0)
# moved from 139 to 137 as the data sender; for shooting thermal frame;
# reimplemented it from loading an image to getting data directly from melexis, reshaped and successfully sent to 139
#
# preparation for weekly, weekly : Sentiment(polarity=0.425, subjectivity=0.675)
# moved from 139 to 137 as the data sender; for shooting thermal frame;
# reimplemented it from loading an image to getting data directly from melexis, reshaped and successfully sent to 139
#
# preparation for weekly, weekly : Sentiment(polarity=0.425, subjectivity=0.675)
# commenting the Marek's can desing, coding it as master slave and testing offline accordingly, commited on Monday, summary sent over email to BCF team : Sentiment(polarity=0.0, subjectivity=0.0)
# commenting the Marek's can desing, coding it as master slave and testing offline accordingly, commited on Monday, summary sent over email to BCF team : Sentiment(polarity=0.0, subjectivity=0.0)
# commenting the Marek's can desing, coding it as master slave and testing offline accordingly, commited, summary sent over email to BCF team
#
# weekly call : Sentiment(polarity=0.0, subjectivity=0.0)
# implemented and tested reshaping the thermal frame and making an image out of it on 139 : Sentiment(polarity=0.0, subjectivity=0.0)
# preparation for and meeting with Marek regarding CAN protocol,
# few checks on RPIs  : Sentiment(polarity=-0.2, subjectivity=0.1)
# code analysis, work plan, daily : Sentiment(polarity=0.0, subjectivity=0.0)
# code analysis (Rob's repo), plan, ideas : Sentiment(polarity=0.0, subjectivity=0.0)
# working on analysis of vendor results - new look at Batch A as per request - updated excel file results
# daily : Sentiment(polarity=0.06818181818181818, subjectivity=0.22727272727272727)
# working on analysis of vendor results - new look at Batch A as per request - updated excel file results
# daily : Sentiment(polarity=0.06818181818181818, subjectivity=0.22727272727272727)
# working on analysis of vendor results - new look at Batch A as per request - updated excel file results
# daily, meeting with one of the vendors : Sentiment(polarity=0.06818181818181818, subjectivity=0.22727272727272727)
# working on analysis of vendor results - new look at Batch A as per request - updated presentation final stage
# daily : Sentiment(polarity=0.04545454545454545, subjectivity=0.48484848484848486)
# one of the vendors APIs, docu etc. analysis : Sentiment(polarity=0.0, subjectivity=0.0)
# working on analysis of vendor results - new look at Batch A as per request
# daily  : Sentiment(polarity=0.06818181818181818, subjectivity=0.22727272727272727)
# working on analysis of vendors results - new look at batch A as per request; meeting with Josh, Rob (Wednesday)
#  daily : Sentiment(polarity=0.06818181818181818, subjectivity=0.22727272727272727)
# working on analysis of vendors' results - new look at Batch A as per request - mostly updating GT tables and scripts
# daily  : Sentiment(polarity=0.21212121212121213, subjectivity=0.3181818181818182)
# working on analysis of vendors' results - new look at Batch A as per request - GT tables
# daily : Sentiment(polarity=0.06818181818181818, subjectivity=0.22727272727272727)
# working on analysis of vendor results - new look at Batch A as per request - updated excel file results
# daily : Sentiment(polarity=0.06818181818181818, subjectivity=0.22727272727272727)
# working on analysis of vendor results - new look at Batch A as per request - updated excel file results
# daily : Sentiment(polarity=0.06818181818181818, subjectivity=0.22727272727272727)
# code analysis, work plan, daily : Sentiment(polarity=0.0, subjectivity=0.0)
# code analysis (Rob's repo), plan, ideas : Sentiment(polarity=0.0, subjectivity=0.0)
# plan committed to github, docu reading, nlp readings, meeting with vendor, briefing : Sentiment(polarity=0.0, subjectivity=0.0)
# inside bcf discussions, some readings : Sentiment(polarity=0.0, subjectivity=0.0)
# inside bcf discussions, some readings : Sentiment(polarity=0.0, subjectivity=0.0)
# commenting the Marek's can desing, coding it as master slave and testing offline accordingly, commited on Monday, summary sent over email to BCF team : Sentiment(polarity=0.0, subjectivity=0.0)
# commenting the Marek's can desing, coding it as master slave and testing offline accordingly, commited on Monday, summary sent over email to BCF team : Sentiment(polarity=0.0, subjectivity=0.0)
# commenting the Marek's can desing, coding it as master slave and testing offline accordingly, commited, summary sent over email to BCF team
#
# weekly call : Sentiment(polarity=0.0, subjectivity=0.0)
# Further installation on 139 and making some notes on the process (that were reported on next weekly - to automate that with aptly/artifactory etc. to avoid ABI bugs).
# Inside discussions (bcf about deltathermal - flask etc.) : Sentiment(polarity=0.0, subjectivity=0.25)
# Further installation on 139 and making some notes on the process (that were reported on next weekly - to automate that with aptly/artifactory etc. to avoid ABI bugs).
# Inside discussions (bcf about deltathermal - flask etc.) : Sentiment(polarity=0.0, subjectivity=0.25)
# vendor integration - documentation / env installation / choosing data : Sentiment(polarity=0.0, subjectivity=0.0)
# vendor itegration - trying to connect to sandbox and resolving modules issues : Sentiment(polarity=0.0, subjectivity=0.0)
# vendor results interpretation, integration project, presentation modification : Sentiment(polarity=0.0, subjectivity=0.0)
# vendor integration - documentation / env installation / choosing data : Sentiment(polarity=0.0, subjectivity=0.0)
# vendor itegration - trying to connect to sandbox and resolving modules issues : Sentiment(polarity=0.0, subjectivity=0.0)
# vendor results interpretation, integration project, presentation modification : Sentiment(polarity=0.0, subjectivity=0.0)
# Tried to detect and shoot images on 139, dependencies installation (it's totally undocumented, only some readme.md, doing it blindly from some descriptions from internet). (this is logged for both 16th and 17th) : Sentiment(polarity=-0.16666666666666666, subjectivity=0.8055555555555555)
# Tried to detect and shoot images on 139, dependencies installation (it's totally undocumented, only some readme.md, doing it blindly from some descriptions from internet). (this is logged for both 16th and 17th) : Sentiment(polarity=-0.16666666666666666, subjectivity=0.8055555555555555)

# %%
df_com["polarity"] = df_com.apply(lambda x: TextBlob(x['comment']).sentiment.polarity, axis = 1)
# Out:
# C:\Users\macgu\AppData\Local\Temp\ipykernel_7480\2521278807.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_com["polarity"] = df_com.apply(lambda x: TextBlob(x['comment']).sentiment.polarity, axis = 1)

# %%
df3["subjectivity"] = df3.apply(lambda x: TextBlob(x['comment']).sentiment.subjectivity, axis = 1)
# Out:
# C:\Users\macgu\AppData\Local\Temp\ipykernel_7480\16039429.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["subjectivity"] = df3.apply(lambda x: TextBlob(x['comment']).sentiment.subjectivity, axis = 1)

# %%
df3.describe()
# Out:
#        userId   polarity  subjectivity
# count    66.0  66.000000     66.000000
# mean     20.0   0.034451      0.168343
# std       0.0   0.115543      0.257986
# min      20.0  -0.200000      0.000000
# 25%      20.0   0.000000      0.000000
# 50%      20.0   0.000000      0.000000
# 75%      20.0   0.068182      0.227273
# max      20.0   0.425000      1.000000

# %%
import matplotlib.pyplot as plt

# %%
df_com.describe()
# Out:
#        userId   polarity  subjectivity
# count    66.0  66.000000     66.000000
# mean     20.0   0.034451      0.168343
# std       0.0   0.115543      0.257986
# min      20.0  -0.200000      0.000000
# 25%      20.0   0.000000      0.000000
# 50%      20.0   0.000000      0.000000
# 75%      20.0   0.068182      0.227273
# max      20.0   0.425000      1.000000

# %%
def sentiment(x):
    if x < 0:
        return 'neg'
    elif x==0:
        return 'neu'
    else:
        return 'pos'

    df_com['polarity'] = df_com['polarity'].map(lambda x: sentiment(x))

# %%
plt.bar(df_com.polarity.value_counts().index, df_com.polarity.value_counts())
# Out:
# <BarContainer object of 9 artists>

# %%
df66 = df3

# %%
pip install vaderSentiment
# Out:
# Collecting vaderSentiment
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
# Requirement already satisfied: requests in c:\projekty\pythonproject4\venv\lib\site-packages (from vaderSentiment) (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\projekty\pythonproject4\venv\lib\site-packages (from requests->vaderSentiment) (1.26.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\projekty\pythonproject4\venv\lib\site-packages (from requests->vaderSentiment) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\projekty\pythonproject4\venv\lib\site-packages (from requests->vaderSentiment) (2.0.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\projekty\pythonproject4\venv\lib\site-packages (from requests->vaderSentiment) (2021.10.8)
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.2
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.3.1; however, version 22.2.2 is available.
# You should consider upgrading via the 'c:\projekty\pythonproject4\venv\scripts\python.exe -m pip install --upgrade pip' command.

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from vaderSentiment import vaderSentiment

analyzer = SentimentIntensityAnalyzer()

for sentence in df66['comment']:
    vs = analyzer.polarity_scores(sentence)
    print("{:-<65} {}".format(sentence, str(vs)))
# Out:
# implemented and tested reshaping the thermal frame and making an image out of it on 139 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# preparation for and meeting with Marek regarding CAN protocol,
# few checks on RPIs  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# weekly, preparation for weekly, trying to get thermal frame through i2c, not detected, tried in next days (reporting here) consulted it with Andy on Wednesday {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# working on analysis of vendors results - new look at batch A as per request {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# working on analysis of vendors' results - new look at Batch A as per request - mostly updating GT tables and scripts
# daily  {'neg': 0.0, 'neu': 0.886, 'pos': 0.114, 'compound': 0.4278}
# working on analysis of vendors' results - new look at Batch A as per request - GT tables
# daily {'neg': 0.0, 'neu': 0.864, 'pos': 0.136, 'compound': 0.4278}
# working on analysis of vendor results - new look at Batch A as per request - updated excel file results
# daily, meeting with one of the vendors {'neg': 0.0, 'neu': 0.897, 'pos': 0.103, 'compound': 0.4588}
# working on analysis of vendor results - new look at Batch A as per request - updated presentation final stage
# daily {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# one of the vendors APIs, docu etc. analysis---------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# plan committed to github, docu reading, nlp readings, meeting with vendor, briefing {'neg': 0.0, 'neu': 0.84, 'pos': 0.16, 'compound': 0.2732}
# presentation for CTO, daily, meeting with CTO-------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# presentation for CTO, updated CE results------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Presentation for CTO--------------------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Presentation for CTO, daily, meeting with CTO-------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# working on HS results-------------------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# working on HS results
# daily-------------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# metrics GT matrix update (strong, good) and HS rerun for them, daily {'neg': 0.0, 'neu': 0.499, 'pos': 0.501, 'compound': 0.8415}
# metrics GT matrix update (strong, good) and HS rerun for them,
# daily {'neg': 0.0, 'neu': 0.499, 'pos': 0.501, 'compound': 0.8415}
# working on analysis of vendors results--------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# working on analysis of vendors results--------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# working on analysis of vendor results - new look at Batch A as per request
# daily  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# tasks estimation, meeting with Marek, sharepoint space ---------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# tasks estimation, meeting with Marek, sharepoint space ---------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# testing on the rpis over vpn,  preparation for weekly, weekly---- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# testing on the rpis over vpn,  preparation for weekly, weekly---- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# weekly, preparation for weekly, trying to get thermal frame through i2c, not detected, tried in next days (reporting here) consulted it with Andy on Wednesday {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# installing dependencies on .139 (possible ABI issues)
# meeting with Marek
# weekly {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# installing dependencies on .139 (possible ABI issues)
# meeting with Marek
# weekly {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# moved from 139 to 137 as the data sender; for shooting thermal frame;
# reimplemented it from loading an image to getting data directly from melexis, reshaped and successfully sent to 139
#
# preparation for weekly, weekly {'neg': 0.0, 'neu': 0.914, 'pos': 0.086, 'compound': 0.4939}
# moved from 139 to 137 as the data sender; for shooting thermal frame;
# reimplemented it from loading an image to getting data directly from melexis, reshaped and successfully sent to 139
#
# preparation for weekly, weekly {'neg': 0.0, 'neu': 0.914, 'pos': 0.086, 'compound': 0.4939}
# commenting the Marek's can desing, coding it as master slave and testing offline accordingly, commited on Monday, summary sent over email to BCF team {'neg': 0.061, 'neu': 0.939, 'pos': 0.0, 'compound': -0.128}
# commenting the Marek's can desing, coding it as master slave and testing offline accordingly, commited on Monday, summary sent over email to BCF team {'neg': 0.061, 'neu': 0.939, 'pos': 0.0, 'compound': -0.128}
# commenting the Marek's can desing, coding it as master slave and testing offline accordingly, commited, summary sent over email to BCF team
#
# weekly call {'neg': 0.061, 'neu': 0.939, 'pos': 0.0, 'compound': -0.128}
# implemented and tested reshaping the thermal frame and making an image out of it on 139 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# preparation for and meeting with Marek regarding CAN protocol,
# few checks on RPIs  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# code analysis, work plan, daily---------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# code analysis (Rob's repo), plan, ideas-------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# working on analysis of vendor results - new look at Batch A as per request - updated excel file results
# daily {'neg': 0.0, 'neu': 0.87, 'pos': 0.13, 'compound': 0.4588}
# working on analysis of vendor results - new look at Batch A as per request - updated excel file results
# daily {'neg': 0.0, 'neu': 0.87, 'pos': 0.13, 'compound': 0.4588}
# working on analysis of vendor results - new look at Batch A as per request - updated excel file results
# daily, meeting with one of the vendors {'neg': 0.0, 'neu': 0.897, 'pos': 0.103, 'compound': 0.4588}
# working on analysis of vendor results - new look at Batch A as per request - updated presentation final stage
# daily {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# one of the vendors APIs, docu etc. analysis---------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# working on analysis of vendor results - new look at Batch A as per request
# daily  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# working on analysis of vendors results - new look at batch A as per request; meeting with Josh, Rob (Wednesday)
#  daily {'neg': 0.153, 'neu': 0.847, 'pos': 0.0, 'compound': -0.5574}
# working on analysis of vendors' results - new look at Batch A as per request - mostly updating GT tables and scripts
# daily  {'neg': 0.0, 'neu': 0.886, 'pos': 0.114, 'compound': 0.4278}
# working on analysis of vendors' results - new look at Batch A as per request - GT tables
# daily {'neg': 0.0, 'neu': 0.864, 'pos': 0.136, 'compound': 0.4278}
# working on analysis of vendor results - new look at Batch A as per request - updated excel file results
# daily {'neg': 0.0, 'neu': 0.87, 'pos': 0.13, 'compound': 0.4588}
# working on analysis of vendor results - new look at Batch A as per request - updated excel file results
# daily {'neg': 0.0, 'neu': 0.87, 'pos': 0.13, 'compound': 0.4588}
# code analysis, work plan, daily---------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# code analysis (Rob's repo), plan, ideas-------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# plan committed to github, docu reading, nlp readings, meeting with vendor, briefing {'neg': 0.0, 'neu': 0.84, 'pos': 0.16, 'compound': 0.2732}
# inside bcf discussions, some readings---------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# inside bcf discussions, some readings---------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# commenting the Marek's can desing, coding it as master slave and testing offline accordingly, commited on Monday, summary sent over email to BCF team {'neg': 0.061, 'neu': 0.939, 'pos': 0.0, 'compound': -0.128}
# commenting the Marek's can desing, coding it as master slave and testing offline accordingly, commited on Monday, summary sent over email to BCF team {'neg': 0.061, 'neu': 0.939, 'pos': 0.0, 'compound': -0.128}
# commenting the Marek's can desing, coding it as master slave and testing offline accordingly, commited, summary sent over email to BCF team
#
# weekly call {'neg': 0.061, 'neu': 0.939, 'pos': 0.0, 'compound': -0.128}
# Further installation on 139 and making some notes on the process (that were reported on next weekly - to automate that with aptly/artifactory etc. to avoid ABI bugs).
# Inside discussions (bcf about deltathermal - flask etc.) {'neg': 0.059, 'neu': 0.941, 'pos': 0.0, 'compound': -0.296}
# Further installation on 139 and making some notes on the process (that were reported on next weekly - to automate that with aptly/artifactory etc. to avoid ABI bugs).
# Inside discussions (bcf about deltathermal - flask etc.) {'neg': 0.059, 'neu': 0.941, 'pos': 0.0, 'compound': -0.296}
# vendor integration - documentation / env installation / choosing data {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# vendor itegration - trying to connect to sandbox and resolving modules issues {'neg': 0.0, 'neu': 0.809, 'pos': 0.191, 'compound': 0.3818}
# vendor results interpretation, integration project, presentation modification {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# vendor integration - documentation / env installation / choosing data {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# vendor itegration - trying to connect to sandbox and resolving modules issues {'neg': 0.0, 'neu': 0.809, 'pos': 0.191, 'compound': 0.3818}
# vendor results interpretation, integration project, presentation modification {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Tried to detect and shoot images on 139, dependencies installation (it's totally undocumented, only some readme.md, doing it blindly from some descriptions from internet). (this is logged for both 16th and 17th) {'neg': 0.072, 'neu': 0.928, 'pos': 0.0, 'compound': -0.34}
# Tried to detect and shoot images on 139, dependencies installation (it's totally undocumented, only some readme.md, doing it blindly from some descriptions from internet). (this is logged for both 16th and 17th) {'neg': 0.072, 'neu': 0.928, 'pos': 0.0, 'compound': -0.34}

# %%
df66["pos"] = df_com.apply(lambda x: analyzer.polarity_scores(x['comment'])['pos'], axis = 1)
df_com
# Out:
# C:\Users\macgu\AppData\Local\Temp\ipykernel_7480\1807519583.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df66["pos"] = df_com.apply(lambda x: analyzer.polarity_scores(x['comment'])['pos'], axis = 1)
#       userId           logDayFrom             logDayTo  \
# 1190      20  2020-11-24 20:00:00  2020-11-24 22:00:00
# 1191      20  2020-11-25 20:00:00  2020-11-25 22:00:00
# 1192      20  2020-11-09 18:00:00  2020-11-09 23:00:00
# 1202      20  2020-11-10 12:00:00  2020-11-10 20:00:00
# 1203      20  2020-11-12 12:00:00  2020-11-12 20:00:00
# ...      ...                  ...                  ...
# 2037      20  2020-11-26 10:00:00  2020-11-26 18:00:00
# 2038      20  2020-11-27 10:00:00  2020-11-27 18:00:00
# 2039      20  2020-11-30 10:30:00  2020-11-30 18:30:00
# 2040      20  2020-11-16 20:00:00  2020-11-16 21:00:00
# 2041      20  2020-11-16 20:00:00  2020-11-16 21:00:00
#
#                                                 comment  polarity  \
# 1190  implemented and tested reshaping the thermal f...  0.000000
# 1191  preparation for and meeting with Marek regardi... -0.200000
# 1192  weekly, preparation for weekly, trying to get ...  0.000000
# 1202  working on analysis of vendors results - new l...  0.136364
# 1203  working on analysis of vendors' results - new ...  0.212121
# ...                                                 ...       ...
# 2037  vendor integration - documentation / env insta...  0.000000
# 2038  vendor itegration - trying to connect to sandb...  0.000000
# 2039  vendor results interpretation, integration pro...  0.000000
# 2040  Tried to detect and shoot images on 139, depen... -0.166667
# 2041  Tried to detect and shoot images on 139, depen... -0.166667
#
#       subjectivity    pos
# 1190      0.000000  0.000
# 1191      0.100000  0.000
# 1192      0.000000  0.000
# 1202      0.454545  0.000
# 1203      0.318182  0.114
# ...            ...    ...
# 2037      0.000000  0.000
# 2038      0.000000  0.191
# 2039      0.000000  0.000
# 2040      0.805556  0.000
# 2041      0.805556  0.000
#
# [66 rows x 7 columns]

# %%
df66["neu"] = df_com.apply(lambda x: analyzer.polarity_scores(x['comment'])['neu'], axis = 1)
df_com
# Out:
# C:\Users\macgu\AppData\Local\Temp\ipykernel_7480\3282729076.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df66["neu"] = df_com.apply(lambda x: analyzer.polarity_scores(x['comment'])['neu'], axis = 1)
#       userId           logDayFrom             logDayTo  \
# 1190      20  2020-11-24 20:00:00  2020-11-24 22:00:00
# 1191      20  2020-11-25 20:00:00  2020-11-25 22:00:00
# 1192      20  2020-11-09 18:00:00  2020-11-09 23:00:00
# 1202      20  2020-11-10 12:00:00  2020-11-10 20:00:00
# 1203      20  2020-11-12 12:00:00  2020-11-12 20:00:00
# ...      ...                  ...                  ...
# 2037      20  2020-11-26 10:00:00  2020-11-26 18:00:00
# 2038      20  2020-11-27 10:00:00  2020-11-27 18:00:00
# 2039      20  2020-11-30 10:30:00  2020-11-30 18:30:00
# 2040      20  2020-11-16 20:00:00  2020-11-16 21:00:00
# 2041      20  2020-11-16 20:00:00  2020-11-16 21:00:00
#
#                                                 comment  polarity  \
# 1190  implemented and tested reshaping the thermal f...  0.000000
# 1191  preparation for and meeting with Marek regardi... -0.200000
# 1192  weekly, preparation for weekly, trying to get ...  0.000000
# 1202  working on analysis of vendors results - new l...  0.136364
# 1203  working on analysis of vendors' results - new ...  0.212121
# ...                                                 ...       ...
# 2037  vendor integration - documentation / env insta...  0.000000
# 2038  vendor itegration - trying to connect to sandb...  0.000000
# 2039  vendor results interpretation, integration pro...  0.000000
# 2040  Tried to detect and shoot images on 139, depen... -0.166667
# 2041  Tried to detect and shoot images on 139, depen... -0.166667
#
#       subjectivity    pos    neu
# 1190      0.000000  0.000  1.000
# 1191      0.100000  0.000  1.000
# 1192      0.000000  0.000  1.000
# 1202      0.454545  0.000  1.000
# 1203      0.318182  0.114  0.886
# ...            ...    ...    ...
# 2037      0.000000  0.000  1.000
# 2038      0.000000  0.191  0.809
# 2039      0.000000  0.000  1.000
# 2040      0.805556  0.000  0.928
# 2041      0.805556  0.000  0.928
#
# [66 rows x 8 columns]

# %%
df66["neg"] = df_com.apply(lambda x: analyzer.polarity_scores(x['comment'])['neg'], axis = 1)
# Out:
# C:\Users\macgu\AppData\Local\Temp\ipykernel_7480\2510958666.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df66["neg"] = df_com.apply(lambda x: analyzer.polarity_scores(x['comment'])['neg'], axis = 1)

# %%
df66["compound"] = df_com.apply(lambda x: analyzer.polarity_scores(x['comment'])['compound'], axis = 1)
# Out:
# C:\Users\macgu\AppData\Local\Temp\ipykernel_7480\3346425681.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df66["compound"] = df_com.apply(lambda x: analyzer.polarity_scores(x['comment'])['compound'], axis = 1)

# %%
df66.describe()
# Out:
#        userId   polarity  subjectivity        pos        neu        neg  \
# count    66.0  66.000000     66.000000  66.000000  66.000000  66.000000
# mean     20.0   0.034451      0.168343   0.047000   0.941167   0.011833
# std       0.0   0.115543      0.257986   0.099766   0.098244   0.028776
# min      20.0  -0.200000      0.000000   0.000000   0.499000   0.000000
# 25%      20.0   0.000000      0.000000   0.000000   0.901250   0.000000
# 50%      20.0   0.000000      0.000000   0.000000   1.000000   0.000000
# 75%      20.0   0.068182      0.227273   0.086000   1.000000   0.000000
# max      20.0   0.425000      1.000000   0.501000   1.000000   0.153000
#
#         compound
# count  66.000000
# mean    0.088597
# std     0.267102
# min    -0.557400
# 25%     0.000000
# 50%     0.000000
# 75%     0.273200
# max     0.841500
